# %% [markdown]
# # Code to generate the json file for the sunburst by thematic

# %%
import pandas as pd
import numpy as np
import json

# %% [markdown]
# To open the  'Study programs - Bachelor' of 'UNITA_study_programs (1).xlsx'

# %%
df_bachelor = pd.read_excel('UNITA_study_programs (1)(modif).xlsx', sheet_name='Study programs - Bachelor')

# %%
df_bachelor
# Out:
#              University                                Faculty  \
# 0     CULTURAL HERITAGE                                    NaN
# 1                   UBI                       Arts and Letters
# 2                   UBI                       Arts and Letters
# 3                   UBI                       Arts and Letters
# 4                   UBI                       Arts and Letters
# 5                   UBI                            Engineering
# 6                   UBI                            Engineering
# 7                UNIZAR                                    NaN
# 8                  UPPA                                    NaN
# 9                  USMB  Lettres, Langues et Sciences Humaines
# 10                 USMB  Lettres, Langues et Sciences Humaines
# 11                 USMB  Lettres, Langues et Sciences Humaines
# 12                 USMB                   Sciences et Montagne
# 13                 USMB                   Sciences et Montagne
# ...

# %% [markdown]
# To keep only the rows with a study program's name not NaN :

# %%
df_bachelor = df_bachelor[df_bachelor['Study program’s name'].notna()]
df_bachelor
# Out:
#              University                                Faculty  \
# 1                   UBI                       Arts and Letters
# 2                   UBI                       Arts and Letters
# 3                   UBI                       Arts and Letters
# 4                   UBI                       Arts and Letters
# 5                   UBI                            Engineering
# 6                   UBI                            Engineering
# 9                  USMB  Lettres, Langues et Sciences Humaines
# 10                 USMB  Lettres, Langues et Sciences Humaines
# 11                 USMB  Lettres, Langues et Sciences Humaines
# 12                 USMB                   Sciences et Montagne
# 13                 USMB                   Sciences et Montagne
# 14                 USMB              IAE Savoie Mont Blanc\n\n
# 15  University of Turin                                    NaN
# 16                 UPPA                                    SSH
# ...

# %%
df_bc_uvt = pd.read_excel('UNITA_study_programs_database_UVT_copy.xlsx', sheet_name='Study programs - Bachelor')

# %%
df_bc_uvt
# Out:
#                       University  \
# 0   West University of Timișoara
# 1   West University of Timișoara
# 2   West University of Timișoara
# 3   West University of Timișoara
# 4   West University of Timișoara
# ..                           ...
# 73  West University of Timișoara
# 74  West University of Timișoara
# 75  West University of Timișoara
# 76  West University of Timișoara
# 77  West University of Timișoara
#
#                                               Faculty  \
# 0                          Faculty of Arts and Design
# 1                          Faculty of Arts and Design
# 2                          Faculty of Arts and Design
# 3                          Faculty of Arts and Design
# 4                          Faculty of Arts and Design
# ..                                                ...
# 73  Faculty of Political Science, Philosophy and C...
# 74  Faculty of Political Science, Philosophy and C...
# 75  Faculty of Political Science, Philosophy and C...
# ...

# %% [markdown]
# To keep only the rows in one of thematic

# %%
df_bc_uvt = df_bc_uvt[(df_bc_uvt['Thematic area\n(Cultural heritage, Renewable energy,  Circular economy, NONE)']).notna()]

# %% [markdown]
# To drop columns unnecessary

# %%
df_bc_uvt=df_bc_uvt.drop(columns=['Thematic area\n(Cultural heritage, Renewable energy,  Circular economy, NONE).1','Unnamed: 11','Unnamed: 12'])

# %% [markdown]
# To append the data of df_bc_uvt in df_bachelor

# %%
df_bachelor = df_bachelor.append(df_bc_uvt,ignore_index=True, sort=False)

# %% [markdown]
# To open UNITA_study_programs-UNITO_DEFINITIVO

# %%
df_bc_unito = pd.read_excel('UNITA_study_programs-UNITO_DEFINITIVO.xlsx', sheet_name='Study programs - Bachelor')

# %% [markdown]
# To keep only the rows in one of the thematic

# %%
df_bc_unito=df_bc_unito[(df_bc_unito['Thematic area\n(Cultural heritage, Renewable energy,  Circular economy, NONE)']) != 'NONE']

# %% [markdown]
# To append the data in df_bachelor

# %%
df_bachelor = df_bachelor.append(df_bc_unito,ignore_index=True, sort=False)

# %%
df_bachelor
# Out:
#    University           Faculty                              Department  \
# 0         UBI  Arts and Letters  Communication, Philosophy and Politics
# 1         UBI  Arts and Letters  Communication, Philosophy and Politics
# 2         UBI  Arts and Letters                         Arts Department
# 3         UBI  Arts and Letters                                 Letters
# 4         UBI       Engineering      Civil Engineering and Architecture
# ..        ...               ...                                     ...
# 81      UNITO               NaN                           Studi storici
# 82      UNITO               NaN                           Studi Storici
# 83      UNITO               NaN           Studi Umanistici / Humanities
# 84      UNITO               NaN          Cultures, Politics and Society
# 85      UNITO               NaN                                   DBMSS
#
#    Degree / study cycle Level of qualification - according to EQF  \
# ...

# %% [markdown]
# To open the  'Study programs - Master' of 'UNITA_study_programs (1).xlsx'

# %%
df_master = pd.read_excel('UNITA_study_programs (1)(modif).xlsx', sheet_name='Study programs - Master')

# %% [markdown]
# To keep only the rows with a study program's name not NaN :

# %%
df_master = df_master[df_master['Study program’s name'].notna()]
df_master
# Out:
#                  University                                 Faculty  \
# 1                       UBI                        Arts and Letters
# 2                       UBI                        Arts and Letters
# 3                       UBI                        Arts and Letters
# 4                       UBI                             Engineering
# 5                       UBI                             Engineering
# 6                       UBI                             Engineering
# 7   Universidad de Zaragoza                          Faculty of Law
# 8   Universidad de Zaragoza  School of Engineering and Architecture
# 9   Universidad de Zaragoza                         Faculty of Arts
# 10                     USMB   Lettres, Langues et Sciences Humaines
# 11                     USMB   Lettres, Langues et Sciences Humaines
# 12                     USMB   Lettres, Langues et Sciences Humaines
# 13                     USMB   Lettres, Langues et Sciences Humaines
# ...

# %% [markdown]
# We do the same as with uvt bachelors but for masters

# %%
df_m_uvt = pd.read_excel('UNITA_study_programs_database_UVT_copy.xlsx', sheet_name='Study programs - Master')

# %%
df_m_uvt = df_m_uvt[(df_m_uvt['Thematic area\n(Cultural heritage, Renewable energy,  Circular economy, NONE)']).notna()]

# %%
df_m_uvt=df_m_uvt.drop(columns=['Thematic area\n(Cultural heritage, Renewable energy,  Circular economy, NONE).1','Unnamed: 11','Unnamed: 12'])

# %%
df_master = df_master.append(df_m_uvt,ignore_index=True, sort=False)

# %% [markdown]
# We do the same for UNITO

# %%
df_m_unito = pd.read_excel('UNITA_study_programs-UNITO_DEFINITIVO.xlsx', sheet_name='Study programs - Master')

# %%
df_m_unito=df_m_unito[(df_m_unito['Thematic area\n(Cultural heritage, Renewable energy,  Circular economy, NONE)']) != 'NONE']

# %%
df_master = df_master.append(df_m_unito,ignore_index=True, sort=False)

# %% [markdown]
# To keep only the columns we want (Thematic, Degree/study cycle, University, Study program's name and Number of ECTS) of df_master :

# %%
df_sunburst_thematic_m=pd.DataFrame(data=df_master,columns=['Thematic area\n(Cultural heritage, Renewable energy,  Circular economy, NONE)','Degree / study cycle','University', 'Study program’s name','Total number of ECTS of the program'])

# %% [markdown]
# Same with df_bachelor :

# %%
df_sunburst_thematique = pd.DataFrame(data=df_bachelor,columns=['Thematic area\n(Cultural heritage, Renewable energy,  Circular economy, NONE)','Degree / study cycle','University', 'Study program’s name','Total number of ECTS of the program'])

# %%
df_sunburst_thematique
# Out:
#    Thematic area\n(Cultural heritage, Renewable energy,  Circular economy, NONE)  \
# 0                                   Cultural Heritage
# 1                                   Cultural Heritage
# 2                                   Cultural Heritage
# 3                                   Cultural Heritage
# 4                                   Cultural Heritage
# ..                                                ...
# 81                                  Cultural heritage
# 82                                  Cultural heritage
# 83                                  Cultural heritage
# 84                                   Renewable energy
# 85                                   Renewable energy
#
#    Degree / study cycle University  \
# 0              Bachelor        UBI
# 1              Bachelor        UBI
# 2              Bachelor        UBI
# 3              Bachelor        UBI
# 4              Bachelor        UBI
# ..                  ...        ...
# ...

# %% [markdown]
# To add master's and bachelor's data in the same dataframe :

# %%
df_sunburst_thematique=df_sunburst_thematique.append(df_sunburst_thematic_m,ignore_index=True)

# %% [markdown]
# To add a column for the middle of the sunburst :

# %%
df_sunburst_thematique['center']=1

# %%
df_sunburst_thematique
# Out:
#     Thematic area\n(Cultural heritage, Renewable energy,  Circular economy, NONE)  \
# 0                                    Cultural Heritage
# 1                                    Cultural Heritage
# 2                                    Cultural Heritage
# 3                                    Cultural Heritage
# 4                                    Cultural Heritage
# ..                                                 ...
# 202                                  Cultural heritage
# 203                                  Cultural heritage
# 204                                  Cultural heritage
# 205                                  Cultural heritage
# 206                                   Renewable energy
#
#     Degree / study cycle University  \
# 0               Bachelor        UBI
# 1               Bachelor        UBI
# 2               Bachelor        UBI
# 3               Bachelor        UBI
# 4               Bachelor        UBI
# ..                   ...        ...
# ...

# %% [markdown]
# To have the same RE,CE and CH for all rows :

# %%
df_sunburst_thematique['Thematic area\n(Cultural heritage, Renewable energy,  Circular economy, NONE)']=df_sunburst_thematique['Thematic area\n(Cultural heritage, Renewable energy,  Circular economy, NONE)'].replace({'Cultural Heritage':'Cultural heritage', 'CH':'Cultural heritage', 'CE' : 'Circular economy', 'RE':'Renewable energy' })

# %% [markdown]
# To correct 'University of Turin' in UNITO and 'Universidad de Zaragoza' in UNIZAR :

# %%
df_sunburst_thematique['University']=df_sunburst_thematique['University'].replace({'University of Turin': 'UNITO','Universidad de Zaragoza':'UNIZAR','West University of Timișoara':'UVT'})

# %% [markdown]
# To have Bachelor or Master in all rows :

# %%
df_sunburst_thematique['Degree / study cycle'] = df_sunburst_thematique['Degree / study cycle'].replace({'Bs' : 'Bachelor', 'Bs - Formation en contrat pro' : 'Bachelor', '1rst cycle' : 'Bachelor', "Master's Degree" : 'Master', 'Ms' : 'Master'})

# %% [markdown]
# To replace all \n with a space in 'Study program’s name' :

# %%
df_sunburst_thematique['Study program’s name']=df_sunburst_thematique['Study program’s name'].str.replace('\n', '')

# %%
df_sunburst_thematique['Total number of ECTS of the program'].dtypes
# Out:
# dtype('float64')

# %% [markdown]
# To convert 'Total number of ECTS of the program' in int :

# %%
df_sunburst_thematique = df_sunburst_thematique.astype({'Total number of ECTS of the program': int})

# %%
df_sunburst_thematique
# Out:
#     Thematic area\n(Cultural heritage, Renewable energy,  Circular economy, NONE)  \
# 0                                    Cultural heritage
# 1                                    Cultural heritage
# 2                                    Cultural heritage
# 3                                    Cultural heritage
# 4                                    Cultural heritage
# ..                                                 ...
# 202                                  Cultural heritage
# 203                                  Cultural heritage
# 204                                  Cultural heritage
# 205                                  Cultural heritage
# 206                                   Renewable energy
#
#     Degree / study cycle University  \
# 0               Bachelor        UBI
# 1               Bachelor        UBI
# 2               Bachelor        UBI
# 3               Bachelor        UBI
# 4               Bachelor        UBI
# ..                   ...        ...
# ...

# %% [markdown]
# Reindexing des colonnes

# %%
df_sunburst_thematique = df_sunburst_thematique.reindex(columns = ['center','Thematic area\n(Cultural heritage, Renewable energy,  Circular economy, NONE)','Degree / study cycle','University','Study program’s name','Total number of ECTS of the program'])

# %%
df_sunburst_thematique.rename(columns = {'Total number of ECTS of the program':'ECTS'},inplace=True)

# %%
df_sunburst_thematique
# Out:
#      center  \
# 0         1
# 1         1
# 2         1
# 3         1
# 4         1
# ..      ...
# 202       1
# 203       1
# 204       1
# 205       1
# 206       1
#
#     Thematic area\n(Cultural heritage, Renewable energy,  Circular economy, NONE)  \
# 0                                    Cultural heritage
# 1                                    Cultural heritage
# 2                                    Cultural heritage
# 3                                    Cultural heritage
# 4                                    Cultural heritage
# ..                                                 ...
# 202                                  Cultural heritage
# 203                                  Cultural heritage
# 204                                  Cultural heritage
# 205                                  Cultural heritage
# 206                                   Renewable energy
#
#     Degree / study cycle University  \
# 0               Bachelor        UBI
# ...

# %% [markdown]
# To create a dictonnary with the correct format :

# %%
def create_entries(df):
    entries = []
    # Stopping case
    if df.shape[1] == 2:  # only 2 columns left
        for i in range(df.shape[0]):  # iterating on rows
            entries.append(
                {"name": df.iloc[i, 0],
                 df.columns[-1]: df.iloc[i, 1]}
            )
    # Iterating case
    else:
        values = set(df.iloc[:, 0])  # Getting the set of unique values
        for v in values:
            entries.append(
                {"name": v,
                 # reiterating the process but without the first column
                 # and only the rows with the current value
                 "children": create_entries(
                     df.loc[df.iloc[:, 0] == v].iloc[:, 1:]
                 )}
            )
    return entries

# %%
mydict = {"name": "",
          "children": create_entries(df_sunburst_thematique.iloc[:, 1:])}

# %%
mydict
# Out:
# {'name': '',
#  'children': [{'name': 'Cultural heritage',
#    'children': [{'name': 'Master',
#      'children': [{'name': 'UVT',
#        'children': [{'name': 'Heritage, restoration and curation in the visual arts',
#          'ECTS': 120},
#         {'name': 'Tourism development and planning', 'ECTS': 120},
#         {'name': 'Planning and sustainable development of territory',
#          'ECTS': 120},
#         {'name': 'European Union Law', 'ECTS': 60},
#         {'name': 'Management and European Integration (MIE)', 'ECTS': 120},
#         {'name': 'Literature and Culture - Romanian Contexts, European Contexts',
#          'ECTS': 120},
#         {'name': 'Current trends in the studying Romanian Language',
#          'ECTS': 120},
#         {'name': 'Performing Arts for Theatre', 'ECTS': 120},
#         {'name': 'Management and supervision in child and family welfare',
#          'ECTS': 120},
#         {'name': 'Values-centred social assistance practice', 'ECTS': 120},
# ...

# %%
class MyEncoder(json.JSONEncoder):
    def default(self, obj):
        if isinstance(obj, np.integer):
            return int(obj)
        elif isinstance(obj, np.floating):
            return float(obj)
        elif isinstance(obj, np.ndarray):
            return obj.tolist()
        else:
            return super(MyEncoder, self).default(obj)

# %% [markdown]
# To convert the dictionnary to a json file :

# %%
with open('data_sunburst_thematic.json', 'w') as outfile:
        json.dump(mydict, outfile, indent=4,cls=MyEncoder)
